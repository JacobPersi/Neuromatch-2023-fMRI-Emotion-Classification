# %%
# %run "./1. Data Loading.ipynb"
# Out:
# X: (800, 360, 25)
# Y: (800,)

# %%
from sklearn.decomposition import PCA

# %%
num_components = 8
top_regions = 8

# %%
# Helepr function: 
def run_pca(input_data, num_components):
    pca = PCA(num_components)
    pca.fit(input_data)
    reduced_data = pca.transform(input_data)
    explained_variance_ratio = pca.explained_variance_ratio_
    components = pca.components_
    return (reduced_data, explained_variance_ratio, components)

def explain_data(data):
    reduced_data, explained_variance_ratio, components = run_pca(data, num_components = num_components)
    print(f"PCA Input Shape:\t\t{data.shape}")
    print(f"Explained Variance Shape:\t{explained_variance_ratio.shape}")
    print(f"Components Shape:\t\t{components.shape}")
    print(f"Reduced Data Shape:\t\t{reduced_data.shape}\n")

    print (f"{num_components} components account for {round(np.cumsum(explained_variance_ratio)[-1] * 100, 2)}% of the total variance.\n")
    # Each row in pca.components_ represents a principal component, 
    # and the values within each row indicate the weights of the original variables for that component.
    for component_index, variance in enumerate(explained_variance_ratio):
        print(f"Component {component_index + 1} explained {round(variance * 100, 2)}% of the variance.")
        
        component_loadings = components[component_index]
        absolute_loadings = np.abs(component_loadings)
        most_influential = sorted([(i, value) for i, value in enumerate(absolute_loadings)], key=lambda x: x[1], reverse=True)

        print(f"\tThe top {top_regions} weighted regions in this component are:")
        for loading_index, _ in most_influential[:top_regions]:
            print(f"\t\t[{regions[1][loading_index]}] {regions[0][loading_index]}\twith a weight of {round(component_loadings[loading_index], 4)}")
        print("\n")

# %% [markdown]
# ##### Neutral PCA:

# %%
# Prepare data
neut_timeseries = X[Y == 0]
neut_timeseries_average = np.mean(neut_timeseries, axis=2)
explain_data(neut_timeseries_average)
# Out:
# PCA Input Shape:		(400, 360)
# Explained Variance Shape:	(8,)
# Components Shape:		(8, 360)
# Reduced Data Shape:		(400, 8)
#
# 8 components account for 38.79% of the total variance.
#
# Component 1 explained 15.51% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Posterior-Mu] L_v23ab	with a weight of 0.154
# 		[Posterior-Mu] L_p32	with a weight of 0.1489
# 		[Posterior-Mu] L_10r	with a weight of 0.1453
# 		[Posterior-Mu] L_10d	with a weight of 0.1367
# 		[Posterior-Mu] L_31pv	with a weight of 0.1337
# 		[Posterior-Mu] R_10r	with a weight of 0.1316
# 		[Posterior-Mu] R_v23ab	with a weight of 0.131
# 		[Posterior-Mu] L_a24	with a weight of 0.122
#
#
# Component 2 explained 5.13% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Posterior-Mu] R_10v	with a weight of 0.1788
# 		[Posterior-Mu] L_10r	with a weight of 0.1619
# 		[Posterior-Mu] L_10v	with a weight of 0.1611
# 		[Posterior-Mu] L_10pp	with a weight of 0.1417
# 		[Frontopariet] L_13l	with a weight of 0.1404
# 		[Frontopariet] L_a10p	with a weight of 0.1353
# 		[Frontopariet] L_11l	with a weight of 0.1157
# 		[Frontopariet] R_13l	with a weight of 0.114
#
#
# Component 3 explained 4.7% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Posterior-Mu] R_s32	with a weight of -0.1981
# 		[Posterior-Mu] R_10r	with a weight of -0.1831
# 		[Posterior-Mu] L_v23ab	with a weight of -0.1637
# 		[Posterior-Mu] L_s32	with a weight of -0.1507
# 		[Posterior-Mu] R_v23ab	with a weight of -0.1249
# 		[Posterior-Mu] R_POS1	with a weight of -0.1193
# 		[Posterior-Mu] L_31pv	with a weight of -0.116
# 		[Cingulo-Oper] L_FOP4	with a weight of 0.116
#
#
# Component 4 explained 3.2% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Orbito-Affec] L_pOFC	with a weight of -0.3055
# 		[Frontopariet] L_13l	with a weight of -0.2424
# 		[Frontopariet] R_p47r	with a weight of 0.1483
# 		[Frontopariet] L_OFC	with a weight of -0.1407
# 		[Posterior-Mu] R_47l	with a weight of 0.1399
# 		[Default] R_44	with a weight of 0.1386
# 		[Frontopariet] R_AVI	with a weight of 0.1383
# 		[Posterior-Mu] R_EC	with a weight of 0.1374
#
#
# Component 5 explained 2.9% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Frontopariet] R_13l	with a weight of 0.383
# 		[Orbito-Affec] R_pOFC	with a weight of 0.3344
# 		[Frontopariet] R_11l	with a weight of 0.1809
# 		[Frontopariet] R_a10p	with a weight of 0.1535
# 		[Posterior-Mu] R_25	with a weight of 0.1479
# 		[Posterior-Mu] R_OFC	with a weight of 0.1346
# 		[Posterior-Mu] R_47s	with a weight of 0.1321
# 		[Posterior-Mu] L_s32	with a weight of 0.128
#
#
# Component 6 explained 2.6% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Posterior-Mu] R_s32	with a weight of -0.2359
# 		[Posterior-Mu] L_s32	with a weight of -0.229
# 		[Frontopariet] R_13l	with a weight of -0.1911
# 		[Posterior-Mu] R_10r	with a weight of -0.1651
# 		[Posterior-Mu] L_10r	with a weight of -0.1647
# 		[Cingulo-Oper] L_p32pr	with a weight of -0.1536
# 		[Posterior-Mu] R_25	with a weight of -0.1354
# 		[Cingulo-Oper] L_p24pr	with a weight of -0.1353
#
#
# Component 7 explained 2.44% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Orbito-Affec] L_pOFC	with a weight of 0.2775
# 		[Frontopariet] L_13l	with a weight of 0.1938
# 		[Posterior-Mu] R_10r	with a weight of 0.1551
# 		[Posterior-Mu] L_STSvp	with a weight of -0.1459
# 		[Posterior-Mu] L_47l	with a weight of -0.1285
# 		[Posterior-Mu] L_8BL	with a weight of -0.1283
# 		[Default] L_STSdp	with a weight of -0.1259
# 		[Default] L_45	with a weight of -0.1259
#
#
# Component 8 explained 2.31% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Frontopariet] R_13l	with a weight of -0.19
# 		[Posterior-Mu] R_31a	with a weight of -0.1618
# 		[Orbito-Affec] R_pOFC	with a weight of -0.1535
# 		[Posterior-Mu] L_POS1	with a weight of -0.1466
# 		[Frontopariet] L_RSC	with a weight of -0.1388
# 		[Posterior-Mu] L_PHA2	with a weight of -0.1301
# 		[Posterior-Mu] R_EC	with a weight of 0.1237
# 		[Posterior-Mu] R_47l	with a weight of 0.121

# %% [markdown]
# ##### Fearful PCA:

# %%
# Prepare data
fear_timeseries = X[Y == 1]
fear_timeseries_average = np.mean(fear_timeseries, axis=2)
explain_data(fear_timeseries_average)
# Out:
# PCA Input Shape:		(400, 360)
# Explained Variance Shape:	(8,)
# Components Shape:		(8, 360)
# Reduced Data Shape:		(400, 8)
#
# 8 components account for 33.11% of the total variance.
#
# Component 1 explained 8.77% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Posterior-Mu] L_p32	with a weight of 0.1922
# 		[Posterior-Mu] L_10r	with a weight of 0.1751
# 		[Posterior-Mu] R_10r	with a weight of 0.1694
# 		[Posterior-Mu] L_v23ab	with a weight of 0.1676
# 		[Posterior-Mu] L_10d	with a weight of 0.1596
# 		[Posterior-Mu] L_31pv	with a weight of 0.1561
# 		[Posterior-Mu] R_p32	with a weight of 0.1474
# 		[Posterior-Mu] R_s32	with a weight of 0.1457
#
#
# Component 2 explained 5.5% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Frontopariet] L_a10p	with a weight of 0.178
# 		[Posterior-Mu] R_v23ab	with a weight of -0.1591
# 		[Frontopariet] L_AVI	with a weight of 0.1506
# 		[Posterior-Mu] R_s32	with a weight of -0.1441
# 		[Posterior-Mu] L_10pp	with a weight of 0.1405
# 		[Posterior-Mu] L_v23ab	with a weight of -0.1352
# 		[Frontopariet] R_AVI	with a weight of 0.1346
# 		[Frontopariet] L_11l	with a weight of 0.1326
#
#
# Component 3 explained 4.74% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Frontopariet] R_13l	with a weight of 0.2199
# 		[Posterior-Mu] L_10v	with a weight of 0.2021
# 		[Posterior-Mu] R_47m	with a weight of 0.1578
# 		[Orbito-Affec] R_pOFC	with a weight of 0.1539
# 		[Posterior-Mu] R_10v	with a weight of 0.1531
# 		[Posterior-Mu] L_10r	with a weight of 0.1427
# 		[Posterior-Mu] R_s32	with a weight of 0.1394
# 		[Posterior-Mu] L_s32	with a weight of 0.1368
#
#
# Component 4 explained 3.52% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Posterior-Mu] R_47l	with a weight of -0.1456
# 		[Orbito-Affec] R_pOFC	with a weight of 0.1451
# 		[Frontopariet] R_p47r	with a weight of -0.1438
# 		[Posterior-Mu] R_d23ab	with a weight of -0.1426
# 		[Posterior-Mu] R_25	with a weight of 0.1373
# 		[Frontopariet] R_13l	with a weight of 0.1341
# 		[Posterior-Mu] R_v23ab	with a weight of -0.1261
# 		[Frontopariet] R_a47r	with a weight of -0.1247
#
#
# Component 5 explained 3.08% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Posterior-Mu] R_25	with a weight of -0.2402
# 		[Posterior-Mu] L_s32	with a weight of -0.2288
# 		[Posterior-Mu] R_10v	with a weight of -0.1746
# 		[Frontopariet] L_p10p	with a weight of 0.1639
# 		[Posterior-Mu] R_s32	with a weight of -0.1603
# 		[Posterior-Mu] R_47l	with a weight of -0.1468
# 		[Posterior-Mu] R_EC	with a weight of -0.1287
# 		[Posterior-Mu] R_10r	with a weight of -0.1251
#
#
# Component 6 explained 2.67% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Frontopariet] R_13l	with a weight of -0.1845
# 		[Orbito-Affec] L_pOFC	with a weight of -0.1798
# 		[Posterior-Mu] L_8BL	with a weight of 0.1751
# 		[Orbito-Affec] R_pOFC	with a weight of -0.1562
# 		[Frontopariet] L_44	with a weight of 0.1415
# 		[Default] L_45	with a weight of 0.1361
# 		[Posterior-Mu] L_47l	with a weight of 0.1358
# 		[Frontopariet] L_IFSp	with a weight of 0.1333
#
#
# Component 7 explained 2.58% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Orbito-Affec] L_pOFC	with a weight of -0.3676
# 		[Orbito-Affec] R_pOFC	with a weight of 0.3538
# 		[Frontopariet] R_13l	with a weight of 0.3445
# 		[Frontopariet] L_13l	with a weight of -0.2606
# 		[Frontopariet] L_OFC	with a weight of -0.1765
# 		[Posterior-Mu] R_47m	with a weight of 0.1532
# 		[Frontopariet] R_11l	with a weight of 0.1445
# 		[Posterior-Mu] L_25	with a weight of -0.135
#
#
# Component 8 explained 2.26% of the variance.
# 	The top 8 weighted regions in this component are:
# 		[Posterior-Mu] R_PHA1	with a weight of -0.1607
# 		[Posterior-Mu] R_PHA2	with a weight of -0.1546
# 		[Visual2] R_VMV3	with a weight of -0.1501
# 		[Posterior-Mu] R_PreS	with a weight of -0.1382
# 		[Visual2] R_VMV2	with a weight of -0.137
# 		[Posterior-Mu] L_STSvp	with a weight of 0.1301
# 		[Language] R_PHA3	with a weight of -0.1294
# 		[Cingulo-Oper] R_a24pr	with a weight of -0.1266
