# %%
# %run "./1. Data Loading.ipynb"
# Out:
# X: (800, 360, 25)
# Y: (800,)

# %%
from sklearn.decomposition import PCA

# %%
num_components = 20
top_regions = 10

# %%
# Helepr function: 
def run_pca(input_data, num_components):
    pca = PCA(num_components)
    pca.fit(input_data)
    reduced_data = pca.transform(input_data)
    explained_variance_ratio = pca.explained_variance_ratio_
    components = pca.components_
    return (reduced_data, explained_variance_ratio, components)

def explain_data(data):
    reduced_data, explained_variance_ratio, components = run_pca(data, num_components = num_components)
    print(f"PCA Input Shape:\t\t{data.shape}")
    print(f"Explained Variance Shape:\t{explained_variance_ratio.shape}")
    print(f"Components Shape:\t\t{components.shape}")
    print(f"Reduced Data Shape:\t\t{reduced_data.shape}\n")

    print (f"{num_components} components account for {round(np.cumsum(explained_variance_ratio)[-1] * 100, 2)}% of the total variance.\n")
    # Each row in pca.components_ represents a principal component, 
    # and the values within each row indicate the weights of the original variables for that component.
    for component_index, variance in enumerate(explained_variance_ratio):
        print(f"Component {component_index + 1} explained {round(variance * 100, 2)}% of the variance.")
        
        component_loadings = components[component_index]
        absolute_loadings = np.abs(component_loadings)
        most_influential = sorted([(i, value) for i, value in enumerate(absolute_loadings)], key=lambda x: x[1], reverse=True)

        print(f"\tThe top {top_regions} weighted regions in this component are:")
        for loading_index, _ in most_influential[:top_regions]:
            print(f"\t\t[{regions[1][loading_index]}] {regions[0][loading_index]}\twith a weight of {round(component_loadings[loading_index], 4)}")
        print("\n")

# %% [markdown]
# ##### Neutral PCA:

# %%
# Prepare data
neut_timeseries = X[Y == 0]
neut_timeseries_average = np.mean(neut_timeseries, axis=2)
explain_data(neut_timeseries_average)
# Out:
# PCA Input Shape:		(400, 360)
# Explained Variance Shape:	(20,)
# Components Shape:		(20, 360)
# Reduced Data Shape:		(400, 20)
#
# 20 components account for 54.07% of the total variance.
#
# Component 1 explained 15.51% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] L_v23ab	with a weight of 0.154
# 		[Posterior-Mu] L_p32	with a weight of 0.1489
# 		[Posterior-Mu] L_10r	with a weight of 0.1453
# 		[Posterior-Mu] L_10d	with a weight of 0.1367
# 		[Posterior-Mu] L_31pv	with a weight of 0.1337
# 		[Posterior-Mu] R_10r	with a weight of 0.1316
# 		[Posterior-Mu] R_v23ab	with a weight of 0.131
# 		[Posterior-Mu] L_a24	with a weight of 0.122
# 		[Visual2] L_V8	with a weight of -0.1218
# 		[Posterior-Mu] R_31pv	with a weight of 0.1168
#
#
# Component 2 explained 5.13% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] R_10v	with a weight of 0.1788
# 		[Posterior-Mu] L_10r	with a weight of 0.1619
# 		[Posterior-Mu] L_10v	with a weight of 0.1611
# 		[Posterior-Mu] L_10pp	with a weight of 0.1417
# 		[Frontopariet] L_13l	with a weight of 0.1404
# 		[Frontopariet] L_a10p	with a weight of 0.1353
# 		[Frontopariet] L_11l	with a weight of 0.1157
# 		[Frontopariet] R_13l	with a weight of 0.114
# 		[Auditory] L_LBelt	with a weight of -0.1084
# 		[Orbito-Affec] L_pOFC	with a weight of 0.1075
#
#
# Component 3 explained 4.7% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] R_s32	with a weight of -0.1981
# 		[Posterior-Mu] R_10r	with a weight of -0.1831
# 		[Posterior-Mu] L_v23ab	with a weight of -0.1637
# 		[Posterior-Mu] L_s32	with a weight of -0.1507
# 		[Posterior-Mu] R_v23ab	with a weight of -0.1249
# 		[Posterior-Mu] R_POS1	with a weight of -0.1193
# 		[Posterior-Mu] L_31pv	with a weight of -0.116
# 		[Cingulo-Oper] L_FOP4	with a weight of 0.116
# 		[Posterior-Mu] L_POS1	with a weight of -0.1126
# 		[Posterior-Mu] L_d23ab	with a weight of -0.1124
#
#
# Component 4 explained 3.2% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Orbito-Affec] L_pOFC	with a weight of -0.3055
# 		[Frontopariet] L_13l	with a weight of -0.2424
# 		[Frontopariet] R_p47r	with a weight of 0.1483
# 		[Frontopariet] L_OFC	with a weight of -0.1407
# 		[Posterior-Mu] R_47l	with a weight of 0.1399
# 		[Default] R_44	with a weight of 0.1386
# 		[Frontopariet] R_AVI	with a weight of 0.1383
# 		[Posterior-Mu] R_EC	with a weight of 0.1374
# 		[Posterior-Mu] L_47m	with a weight of -0.1352
# 		[Frontopariet] R_a47r	with a weight of 0.1335
#
#
# Component 5 explained 2.9% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Frontopariet] R_13l	with a weight of 0.383
# 		[Orbito-Affec] R_pOFC	with a weight of 0.3344
# 		[Frontopariet] R_11l	with a weight of 0.1809
# 		[Frontopariet] R_a10p	with a weight of 0.1535
# 		[Posterior-Mu] R_25	with a weight of 0.1479
# 		[Posterior-Mu] R_OFC	with a weight of 0.1346
# 		[Posterior-Mu] R_47s	with a weight of 0.1321
# 		[Posterior-Mu] L_s32	with a weight of 0.128
# 		[Posterior-Mu] R_47m	with a weight of 0.1125
# 		[Posterior-Mu] R_v23ab	with a weight of -0.1084
#
#
# Component 6 explained 2.6% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] R_s32	with a weight of -0.2359
# 		[Posterior-Mu] L_s32	with a weight of -0.229
# 		[Frontopariet] R_13l	with a weight of -0.1911
# 		[Posterior-Mu] R_10r	with a weight of -0.1651
# 		[Posterior-Mu] L_10r	with a weight of -0.1647
# 		[Cingulo-Oper] L_p32pr	with a weight of -0.1536
# 		[Posterior-Mu] R_25	with a weight of -0.1354
# 		[Cingulo-Oper] L_p24pr	with a weight of -0.1353
# 		[Cingulo-Oper] L_a24pr	with a weight of -0.1314
# 		[Cingulo-Oper] L_FOP1	with a weight of -0.1261
#
#
# Component 7 explained 2.44% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Orbito-Affec] L_pOFC	with a weight of 0.2775
# 		[Frontopariet] L_13l	with a weight of 0.1938
# 		[Posterior-Mu] R_10r	with a weight of 0.1551
# 		[Posterior-Mu] L_STSvp	with a weight of -0.1459
# 		[Posterior-Mu] L_47l	with a weight of -0.1285
# 		[Posterior-Mu] L_8BL	with a weight of -0.1283
# 		[Default] L_STSdp	with a weight of -0.1259
# 		[Default] L_45	with a weight of -0.1259
# 		[Posterior-Mu] R_p32	with a weight of 0.1223
# 		[Somatomotor] R_FOP2	with a weight of 0.1192
#
#
# Component 8 explained 2.31% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Frontopariet] R_13l	with a weight of -0.19
# 		[Posterior-Mu] R_31a	with a weight of -0.1618
# 		[Orbito-Affec] R_pOFC	with a weight of -0.1535
# 		[Posterior-Mu] L_POS1	with a weight of -0.1466
# 		[Frontopariet] L_RSC	with a weight of -0.1388
# 		[Posterior-Mu] L_PHA2	with a weight of -0.1301
# 		[Posterior-Mu] R_EC	with a weight of 0.1237
# 		[Posterior-Mu] R_47l	with a weight of 0.121
# 		[Posterior-Mu] R_25	with a weight of 0.1182
# 		[Cingulo-Oper] L_FOP5	with a weight of -0.1182
#
#
# Component 9 explained 1.97% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Orbito-Affec] L_pOFC	with a weight of -0.2627
# 		[Frontopariet] L_13l	with a weight of -0.223
# 		[Posterior-Mu] L_25	with a weight of -0.1935
# 		[Posterior-Mu] R_s32	with a weight of -0.1703
# 		[Posterior-Mu] L_10pp	with a weight of 0.161
# 		[Frontopariet] L_11l	with a weight of -0.1332
# 		[Frontopariet] L_a47r	with a weight of -0.1278
# 		[Frontopariet] R_p47r	with a weight of -0.1248
# 		[Frontopariet] L_p47r	with a weight of -0.1229
# 		[Frontopariet] R_IFJp	with a weight of -0.1147
#
#
# Component 10 explained 1.61% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] L_10pp	with a weight of -0.188
# 		[Posterior-Mu] L_10r	with a weight of -0.1802
# 		[Frontopariet] L_13l	with a weight of 0.1729
# 		[Orbito-Affec] R_pOFC	with a weight of 0.1624
# 		[Frontopariet] R_13l	with a weight of 0.162
# 		[Orbito-Affec] L_pOFC	with a weight of 0.1539
# 		[Posterior-Mu] R_47m	with a weight of 0.152
# 		[Posterior-Mu] L_s32	with a weight of -0.1484
# 		[Auditory] L_52	with a weight of 0.1456
# 		[Visual1] R_ProS	with a weight of 0.1394
#
#
# Component 11 explained 1.53% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] R_PHA1	with a weight of 0.2511
# 		[Posterior-Mu] R_PreS	with a weight of 0.2486
# 		[Posterior-Mu] R_EC	with a weight of 0.2283
# 		[Posterior-Mu] L_PHA2	with a weight of 0.2039
# 		[Posterior-Mu] R_PHA2	with a weight of 0.1834
# 		[Posterior-Mu] R_31pv	with a weight of -0.1599
# 		[Posterior-Mu] R_31pd	with a weight of -0.1575
# 		[Posterior-Mu] L_PHA1	with a weight of 0.1461
# 		[Posterior-Mu] L_31pd	with a weight of -0.1412
# 		[Language] L_PHA3	with a weight of 0.1408
#
#
# Component 12 explained 1.38% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Default] R_TGv	with a weight of 0.1992
# 		[Ventral-Mult] R_PeEc	with a weight of 0.1865
# 		[Posterior-Mu] R_s32	with a weight of -0.1775
# 		[Posterior-Mu] R_d23ab	with a weight of 0.1685
# 		[Frontopariet] R_s6-8	with a weight of -0.1556
# 		[Posterior-Mu] L_d23ab	with a weight of 0.1546
# 		[Posterior-Mu] L_10pp	with a weight of 0.1506
# 		[Cingulo-Oper] L_p24pr	with a weight of 0.1481
# 		[Orbito-Affec] R_pOFC	with a weight of 0.1458
# 		[Posterior-Mu] R_TGd	with a weight of 0.1408
#
#
# Component 13 explained 1.31% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] L_10pp	with a weight of 0.2188
# 		[Frontopariet] R_13l	with a weight of -0.1961
# 		[Posterior-Mu] R_EC	with a weight of -0.1948
# 		[Posterior-Mu] L_10v	with a weight of 0.18
# 		[Posterior-Mu] R_10v	with a weight of 0.1736
# 		[Posterior-Mu] L_s32	with a weight of -0.1602
# 		[Frontopariet] R_IFJp	with a weight of 0.1493
# 		[Cingulo-Oper] R_FOP3	with a weight of 0.146
# 		[Frontopariet] L_a10p	with a weight of 0.1423
# 		[Visual2] L_VMV2	with a weight of 0.1381
#
#
# Component 14 explained 1.25% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] L_10r	with a weight of 0.2273
# 		[Posterior-Mu] R_d23ab	with a weight of -0.173
# 		[Posterior-Mu] R_10v	with a weight of -0.1717
# 		[Cingulo-Oper] R_33pr	with a weight of 0.1572
# 		[Frontopariet] L_a10p	with a weight of -0.142
# 		[Somatomotor] L_5m	with a weight of -0.1392
# 		[Frontopariet] L_33pr	with a weight of 0.1293
# 		[Cingulo-Oper] L_5mv	with a weight of -0.1272
# 		[Posterior-Mu] R_10pp	with a weight of -0.1256
# 		[Posterior-Mu] L_EC	with a weight of 0.1248
#
#
# Component 15 explained 1.19% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] L_25	with a weight of -0.221
# 		[Posterior-Mu] R_31a	with a weight of 0.204
# 		[Posterior-Mu] R_d23ab	with a weight of 0.1726
# 		[Posterior-Mu] L_POS1	with a weight of -0.1693
# 		[Posterior-Mu] L_EC	with a weight of 0.1687
# 		[Visual2] L_VMV2	with a weight of 0.1615
# 		[Posterior-Mu] R_31pv	with a weight of 0.1596
# 		[Posterior-Mu] R_s32	with a weight of 0.1527
# 		[Auditory] R_52	with a weight of -0.1527
# 		[Ventral-Mult] L_PeEc	with a weight of 0.1461
#
#
# Component 16 explained 1.1% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] R_25	with a weight of 0.2923
# 		[Posterior-Mu] R_47m	with a weight of -0.2286
# 		[Posterior-Mu] R_s32	with a weight of 0.176
# 		[Posterior-Mu] L_s32	with a weight of -0.1739
# 		[Posterior-Mu] L_47m	with a weight of -0.1718
# 		[Posterior-Mu] R_10v	with a weight of -0.1386
# 		[Frontopariet] L_a10p	with a weight of 0.1339
# 		[Orbito-Affec] L_Pir	with a weight of -0.1242
# 		[Default] R_IFSp	with a weight of -0.123
# 		[Default] L_IFJa	with a weight of -0.1218
#
#
# Component 17 explained 1.05% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] R_s32	with a weight of 0.2689
# 		[Posterior-Mu] L_25	with a weight of -0.1883
# 		[Orbito-Affec] L_pOFC	with a weight of -0.1838
# 		[Frontopariet] L_p10p	with a weight of 0.1622
# 		[Posterior-Mu] R_v23ab	with a weight of -0.1391
# 		[Posterior-Mu] L_EC	with a weight of 0.1273
# 		[Frontopariet] L_a10p	with a weight of 0.1272
# 		[Auditory] R_52	with a weight of 0.1271
# 		[Orbito-Affec] R_pOFC	with a weight of -0.123
# 		[Visual2] R_VMV3	with a weight of -0.121
#
#
# Component 18 explained 1.01% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Frontopariet] R_13l	with a weight of -0.2662
# 		[Visual2] R_VMV3	with a weight of -0.2152
# 		[Language] R_PHA3	with a weight of -0.2104
# 		[Posterior-Mu] L_25	with a weight of 0.1899
# 		[Posterior-Mu] R_10pp	with a weight of 0.1763
# 		[Visual2] R_VMV2	with a weight of -0.1732
# 		[Cingulo-Oper] R_FOP3	with a weight of -0.1645
# 		[Posterior-Mu] R_EC	with a weight of 0.1513
# 		[Somatomotor] R_OP2-3	with a weight of -0.1458
# 		[Visual2] R_VMV1	with a weight of -0.1403
#
#
# Component 19 explained 0.96% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Cingulo-Oper] L_p24pr	with a weight of -0.2416
# 		[Frontopariet] R_13l	with a weight of 0.213
# 		[Frontopariet] L_33pr	with a weight of -0.1925
# 		[Posterior-Mu] L_s32	with a weight of -0.1879
# 		[Posterior-Mu] R_s32	with a weight of 0.1877
# 		[Posterior-Mu] L_PreS	with a weight of -0.1672
# 		[Posterior-Mu] R_d23ab	with a weight of 0.1596
# 		[Somatomotor] L_24dv	with a weight of -0.1478
# 		[Posterior-Mu] R_31pv	with a weight of 0.143
# 		[Posterior-Mu] L_10v	with a weight of 0.1423
#
#
# Component 20 explained 0.94% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] R_s32	with a weight of -0.2656
# 		[Posterior-Mu] L_s32	with a weight of -0.238
# 		[Frontopariet] R_13l	with a weight of 0.1856
# 		[Posterior-Mu] L_25	with a weight of -0.1805
# 		[Posterior-Mu] L_EC	with a weight of 0.1521
# 		[Visual2] L_VMV3	with a weight of -0.1517
# 		[Frontopariet] L_a10p	with a weight of 0.1372
# 		[Auditory] L_52	with a weight of 0.1371
# 		[Frontopariet] R_a10p	with a weight of 0.1256
# 		[Cingulo-Oper] L_p32pr	with a weight of 0.1224

# %% [markdown]
# ##### Fearful PCA:

# %%
# Prepare data
fear_timeseries = X[Y == 1]
fear_timeseries_average = np.mean(fear_timeseries, axis=2)
explain_data(fear_timeseries_average)
# Out:
# PCA Input Shape:		(400, 360)
# Explained Variance Shape:	(20,)
# Components Shape:		(20, 360)
# Reduced Data Shape:		(400, 20)
#
# 20 components account for 49.18% of the total variance.
#
# Component 1 explained 8.77% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] L_p32	with a weight of 0.1922
# 		[Posterior-Mu] L_10r	with a weight of 0.1751
# 		[Posterior-Mu] R_10r	with a weight of 0.1694
# 		[Posterior-Mu] L_v23ab	with a weight of 0.1676
# 		[Posterior-Mu] L_10d	with a weight of 0.1596
# 		[Posterior-Mu] L_31pv	with a weight of 0.1561
# 		[Posterior-Mu] R_p32	with a weight of 0.1474
# 		[Posterior-Mu] R_s32	with a weight of 0.1457
# 		[Posterior-Mu] R_v23ab	with a weight of 0.1408
# 		[Posterior-Mu] L_a24	with a weight of 0.1373
#
#
# Component 2 explained 5.5% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Frontopariet] L_a10p	with a weight of 0.178
# 		[Posterior-Mu] R_v23ab	with a weight of -0.1591
# 		[Frontopariet] L_AVI	with a weight of 0.1506
# 		[Posterior-Mu] R_s32	with a weight of -0.1441
# 		[Posterior-Mu] L_10pp	with a weight of 0.1405
# 		[Posterior-Mu] L_v23ab	with a weight of -0.1352
# 		[Frontopariet] R_AVI	with a weight of 0.1346
# 		[Frontopariet] L_11l	with a weight of 0.1326
# 		[Cingulo-Oper] L_a32pr	with a weight of 0.1231
# 		[Frontopariet] L_a9-46v	with a weight of 0.1231
#
#
# Component 3 explained 4.74% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Frontopariet] R_13l	with a weight of 0.2199
# 		[Posterior-Mu] L_10v	with a weight of 0.2021
# 		[Posterior-Mu] R_47m	with a weight of 0.1578
# 		[Orbito-Affec] R_pOFC	with a weight of 0.1539
# 		[Posterior-Mu] R_10v	with a weight of 0.1531
# 		[Posterior-Mu] L_10r	with a weight of 0.1427
# 		[Posterior-Mu] R_s32	with a weight of 0.1394
# 		[Posterior-Mu] L_s32	with a weight of 0.1368
# 		[Posterior-Mu] L_47m	with a weight of 0.1283
# 		[Frontopariet] R_IFJp	with a weight of 0.1179
#
#
# Component 4 explained 3.52% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] R_47l	with a weight of -0.1456
# 		[Orbito-Affec] R_pOFC	with a weight of 0.1451
# 		[Frontopariet] R_p47r	with a weight of -0.1438
# 		[Posterior-Mu] R_d23ab	with a weight of -0.1426
# 		[Posterior-Mu] R_25	with a weight of 0.1373
# 		[Frontopariet] R_13l	with a weight of 0.1341
# 		[Posterior-Mu] R_v23ab	with a weight of -0.1261
# 		[Frontopariet] R_a47r	with a weight of -0.1247
# 		[Cingulo-Oper] L_FOP3	with a weight of 0.1228
# 		[Posterior-Mu] L_10v	with a weight of 0.1176
#
#
# Component 5 explained 3.08% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] R_25	with a weight of -0.2402
# 		[Posterior-Mu] L_s32	with a weight of -0.2288
# 		[Posterior-Mu] R_10v	with a weight of -0.1746
# 		[Frontopariet] L_p10p	with a weight of 0.1639
# 		[Posterior-Mu] R_s32	with a weight of -0.1603
# 		[Posterior-Mu] R_47l	with a weight of -0.1468
# 		[Posterior-Mu] R_EC	with a weight of -0.1287
# 		[Posterior-Mu] R_10r	with a weight of -0.1251
# 		[Posterior-Mu] L_POS1	with a weight of 0.1179
# 		[Posterior-Mu] R_POS1	with a weight of 0.1169
#
#
# Component 6 explained 2.67% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Frontopariet] R_13l	with a weight of -0.1845
# 		[Orbito-Affec] L_pOFC	with a weight of -0.1798
# 		[Posterior-Mu] L_8BL	with a weight of 0.1751
# 		[Orbito-Affec] R_pOFC	with a weight of -0.1562
# 		[Frontopariet] L_44	with a weight of 0.1415
# 		[Default] L_45	with a weight of 0.1361
# 		[Posterior-Mu] L_47l	with a weight of 0.1358
# 		[Frontopariet] L_IFSp	with a weight of 0.1333
# 		[Frontopariet] L_8BM	with a weight of 0.1303
# 		[Frontopariet] L_p47r	with a weight of 0.1282
#
#
# Component 7 explained 2.58% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Orbito-Affec] L_pOFC	with a weight of -0.3676
# 		[Orbito-Affec] R_pOFC	with a weight of 0.3538
# 		[Frontopariet] R_13l	with a weight of 0.3445
# 		[Frontopariet] L_13l	with a weight of -0.2606
# 		[Frontopariet] L_OFC	with a weight of -0.1765
# 		[Posterior-Mu] R_47m	with a weight of 0.1532
# 		[Frontopariet] R_11l	with a weight of 0.1445
# 		[Posterior-Mu] L_25	with a weight of -0.135
# 		[Posterior-Mu] R_47s	with a weight of 0.1335
# 		[Posterior-Mu] L_47s	with a weight of -0.1168
#
#
# Component 8 explained 2.26% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] R_PHA1	with a weight of -0.1607
# 		[Posterior-Mu] R_PHA2	with a weight of -0.1546
# 		[Visual2] R_VMV3	with a weight of -0.1501
# 		[Posterior-Mu] R_PreS	with a weight of -0.1382
# 		[Visual2] R_VMV2	with a weight of -0.137
# 		[Posterior-Mu] L_STSvp	with a weight of 0.1301
# 		[Language] R_PHA3	with a weight of -0.1294
# 		[Cingulo-Oper] R_a24pr	with a weight of -0.1266
# 		[Cingulo-Oper] L_a32pr	with a weight of -0.1253
# 		[Posterior-Mu] R_10r	with a weight of -0.1177
#
#
# Component 9 explained 2.07% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] L_s32	with a weight of -0.2719
# 		[Posterior-Mu] R_25	with a weight of -0.1767
# 		[Posterior-Mu] L_25	with a weight of -0.1609
# 		[Posterior-Mu] R_10d	with a weight of 0.1568
# 		[Frontopariet] L_33pr	with a weight of -0.1541
# 		[Posterior-Mu] R_s32	with a weight of -0.1472
# 		[Posterior-Mu] L_d23ab	with a weight of -0.1455
# 		[Cingulo-Oper] L_p32pr	with a weight of -0.1455
# 		[Posterior-Mu] L_23d	with a weight of -0.1454
# 		[Cingulo-Oper] L_p24pr	with a weight of -0.1449
#
#
# Component 10 explained 1.63% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] R_s32	with a weight of -0.242
# 		[Frontopariet] R_13l	with a weight of 0.2054
# 		[Posterior-Mu] L_s32	with a weight of -0.1774
# 		[Posterior-Mu] L_v23ab	with a weight of 0.1748
# 		[Default] R_TGv	with a weight of 0.1605
# 		[Visual2] L_VMV1	with a weight of -0.1477
# 		[Posterior-Mu] R_a24	with a weight of -0.1457
# 		[Orbito-Affec] R_pOFC	with a weight of 0.1457
# 		[Auditory] R_52	with a weight of 0.1452
# 		[Ventral-Mult] R_PeEc	with a weight of 0.1366
#
#
# Component 11 explained 1.51% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] L_10pp	with a weight of -0.3778
# 		[Posterior-Mu] R_s32	with a weight of 0.3485
# 		[Orbito-Affec] L_pOFC	with a weight of 0.2128
# 		[Posterior-Mu] L_10r	with a weight of -0.1849
# 		[Posterior-Mu] L_s32	with a weight of -0.1731
# 		[Frontopariet] R_a10p	with a weight of -0.1691
# 		[Orbito-Affec] R_pOFC	with a weight of 0.1687
# 		[Posterior-Mu] L_p32	with a weight of -0.1659
# 		[Frontopariet] L_a10p	with a weight of -0.139
# 		[Frontopariet] R_13l	with a weight of 0.1386
#
#
# Component 12 explained 1.48% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] R_EC	with a weight of -0.251
# 		[Frontopariet] R_IFJp	with a weight of 0.2183
# 		[Posterior-Mu] L_s32	with a weight of -0.2063
# 		[Posterior-Mu] R_PHA1	with a weight of -0.1811
# 		[Posterior-Mu] R_PreS	with a weight of -0.1574
# 		[Orbito-Affec] L_pOFC	with a weight of 0.1508
# 		[Posterior-Mu] R_TE1a	with a weight of 0.1472
# 		[Visual2] L_PIT	with a weight of 0.1441
# 		[Cingulo-Oper] R_FOP3	with a weight of 0.1439
# 		[Ventral-Mult] R_PeEc	with a weight of -0.1424
#
#
# Component 13 explained 1.4% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Frontopariet] L_13l	with a weight of -0.2313
# 		[Visual2] L_VMV1	with a weight of -0.1744
# 		[Frontopariet] R_a10p	with a weight of -0.1586
# 		[Frontopariet] R_p47r	with a weight of -0.1472
# 		[Orbito-Affec] L_pOFC	with a weight of -0.146
# 		[Auditory] L_52	with a weight of -0.1445
# 		[Frontopariet] R_RSC	with a weight of -0.1412
# 		[Frontopariet] L_11l	with a weight of -0.1395
# 		[Somatomotor] L_Ig	with a weight of -0.1373
# 		[Visual1] R_ProS	with a weight of -0.1307
#
#
# Component 14 explained 1.31% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] L_25	with a weight of 0.2252
# 		[Cingulo-Oper] L_p24pr	with a weight of -0.2005
# 		[Posterior-Mu] R_d23ab	with a weight of -0.2005
# 		[Somatomotor] L_24dv	with a weight of -0.1995
# 		[Frontopariet] L_IFJp	with a weight of 0.1699
# 		[Posterior-Mu] R_25	with a weight of 0.1371
# 		[Visual2] L_PIT	with a weight of -0.131
# 		[Posterior-Mu] R_PHA2	with a weight of 0.1309
# 		[Posterior-Mu] L_POS1	with a weight of 0.1275
# 		[Somatomotor] R_FOP2	with a weight of -0.1222
#
#
# Component 15 explained 1.24% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] R_EC	with a weight of 0.2384
# 		[Frontopariet] R_13l	with a weight of -0.2106
# 		[Posterior-Mu] L_EC	with a weight of 0.1698
# 		[Posterior-Mu] L_10r	with a weight of 0.1675
# 		[Cingulo-Oper] R_FOP3	with a weight of -0.16
# 		[Posterior-Mu] R_d23ab	with a weight of -0.1465
# 		[Frontopariet] L_POS2	with a weight of 0.1282
# 		[Posterior-Mu] L_47s	with a weight of -0.1212
# 		[Posterior-Mu] R_TE1a	with a weight of -0.1194
# 		[Posterior-Mu] R_PHA1	with a weight of -0.1177
#
#
# Component 16 explained 1.2% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Frontopariet] R_IFJp	with a weight of 0.2122
# 		[Frontopariet] R_a10p	with a weight of -0.2012
# 		[Posterior-Mu] L_25	with a weight of -0.1691
# 		[Posterior-Mu] R_10v	with a weight of 0.1633
# 		[Posterior-Mu] R_TE1a	with a weight of 0.1472
# 		[Posterior-Mu] L_10v	with a weight of 0.1447
# 		[Visual2] L_V8	with a weight of -0.1424
# 		[Posterior-Mu] R_7m	with a weight of 0.1395
# 		[Default] R_IFJa	with a weight of 0.1386
# 		[Visual2] R_LO1	with a weight of -0.1276
#
#
# Component 17 explained 1.11% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Posterior-Mu] R_v23ab	with a weight of 0.2299
# 		[Posterior-Mu] L_s32	with a weight of -0.181
# 		[Posterior-Mu] R_TE1a	with a weight of -0.1799
# 		[Posterior-Mu] L_23d	with a weight of -0.1634
# 		[Posterior-Mu] L_PHA2	with a weight of -0.1576
# 		[Posterior-Mu] L_10v	with a weight of 0.152
# 		[Frontopariet] L_33pr	with a weight of -0.1299
# 		[Posterior-Mu] R_8Ad	with a weight of 0.1258
# 		[Posterior-Mu] R_7m	with a weight of 0.1255
# 		[Visual2] L_VMV1	with a weight of -0.1215
#
#
# Component 18 explained 1.08% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Cingulo-Oper] L_p24pr	with a weight of -0.2257
# 		[Frontopariet] R_13l	with a weight of 0.2159
# 		[Posterior-Mu] R_25	with a weight of -0.2096
# 		[Orbito-Affec] L_Pir	with a weight of 0.193
# 		[Cingulo-Oper] R_FOP3	with a weight of 0.1922
# 		[Cingulo-Oper] L_a24pr	with a weight of -0.1623
# 		[Somatomotor] L_24dv	with a weight of -0.1569
# 		[Cingulo-Oper] L_FOP3	with a weight of 0.1395
# 		[Frontopariet] L_33pr	with a weight of -0.1377
# 		[Posterior-Mu] L_s32	with a weight of 0.1355
#
#
# Component 19 explained 1.03% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Orbito-Affec] R_pOFC	with a weight of -0.1984
# 		[Posterior-Mu] L_PreS	with a weight of 0.1557
# 		[Posterior-Mu] R_10r	with a weight of 0.1521
# 		[Posterior-Mu] R_47m	with a weight of 0.1502
# 		[Posterior-Mu] R_d23ab	with a weight of -0.1491
# 		[Posterior-Mu] R_s32	with a weight of 0.1455
# 		[Posterior-Mu] R_31pv	with a weight of -0.1419
# 		[Posterior-Mu] R_10d	with a weight of 0.1397
# 		[Posterior-Mu] L_10pp	with a weight of -0.1375
# 		[Somatomotor] R_OP2-3	with a weight of 0.1322
#
#
# Component 20 explained 1.01% of the variance.
# 	The top 10 weighted regions in this component are:
# 		[Visual2] R_V8	with a weight of 0.2011
# 		[Posterior-Mu] L_v23ab	with a weight of -0.1983
# 		[Posterior-Mu] L_25	with a weight of -0.1983
# 		[Visual2] L_VVC	with a weight of 0.1843
# 		[Visual2] R_VVC	with a weight of 0.1536
# 		[Visual2] R_VMV3	with a weight of 0.1515
# 		[Frontopariet] L_33pr	with a weight of 0.149
# 		[Orbito-Affec] R_AAIC	with a weight of 0.1467
# 		[Posterior-Mu] R_47s	with a weight of 0.1383
# 		[Posterior-Mu] R_s32	with a weight of -0.1351
