# %%
# %run "./1. Data Loading.ipynb"
# Out:
# X: (800, 360, 25)
# Y: (800,)

# %%
import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter
from sklearn.model_selection import StratifiedKFold

# %%
num_samples = 800
num_features = 360
seq_length = 25
num_classes = 2

num_epochs = 10
num_folds = 5

learning_rate = 0.001
batch_size = 32

# %%
class MultiFeatureTimeSeries(nn.Module):
    def __init__(self, n_features, n_classes):
        super(MultiFeatureTimeSeries, self).__init__()
       
        self.conv1 = nn.Conv1d(n_features, 128, 3)
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool1d(kernel_size = 2)

        self.fc1 = nn.Linear(1408, 128)
        self.fc2 = nn.Linear(128, n_classes)

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu(x)
        x = self.pool(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# %%
k_sampler = StratifiedKFold(n_splits=num_folds, shuffle=True)

# Create a SummaryWriter object
writer = SummaryWriter()

for fold_index, (train_indices, test_indices) in enumerate(k_sampler.split(X, Y)):
    print(f"Fold {fold_index + 1}:")

    train_length = len(train_indices)
    test_length = len(test_indices)
    x_train, y_train = X[train_indices], Y[train_indices]
    x_test, y_test = X[test_indices], Y[test_indices]

    model = MultiFeatureTimeSeries(num_features, num_classes)
    model = model.float()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    for epoch_index in range(num_epochs):
        print(f"\tEpoch {epoch_index}:")

        train_loss = 0.0
        model.train()

        for batch_index in range(0, train_length, batch_size):
            inputs = torch.from_numpy(x_train[batch_index: batch_index + batch_size]).float()
            labels = torch.from_numpy(y_train[batch_index: batch_index + batch_size]).long()

            optimizer.zero_grad()
            
            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Backward pass
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        avg_train_loss = train_loss / (train_length // batch_size)
        print("\t\tTrain Loss:", avg_train_loss)

        # Write training loss to TensorBoard
        writer.add_scalar('Loss/Train', avg_train_loss, fold_index * num_epochs + epoch_index)

        model.eval()

        val_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            inputs = torch.from_numpy(x_test).float()
            labels = torch.from_numpy(y_test).long()

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            # Compute accuracy
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        # Print validation loss and accuracy
        print(f"\t\tValidation Loss: {val_loss / test_length:.4f}")
        print(f"\t\tValidation Accuracy: {(100 * correct / total):.2f}%")

        # Write validation loss and accuracy to TensorBoard
        writer.add_scalar('Loss/Validation', val_loss / test_length, fold_index * num_epochs + epoch_index)
        writer.add_scalar('Accuracy/Validation', 100 * correct / total, fold_index * num_epochs + epoch_index)

# Close the SummaryWriter
writer.close()
# Out:
# Fold 1:
# 	Epoch 0:
# 		Train Loss: 0.17911817806889302
# 		Validation Loss: 0.0002
# 		Validation Accuracy: 99.38%
# 	Epoch 1:
# 		Train Loss: 0.007951541907277714
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 96.88%
# 	Epoch 2:
# 		Train Loss: 0.036610461889719656
# 		Validation Loss: 0.0004
# 		Validation Accuracy: 99.38%
# 	Epoch 3:
# 		Train Loss: 0.037178068166122104
# 		Validation Loss: 0.0006
# 		Validation Accuracy: 96.25%
# 	Epoch 4:
# 		Train Loss: 0.022066512431581486
# 		Validation Loss: 0.0004
# 		Validation Accuracy: 98.75%
# 	Epoch 5:
# 		Train Loss: 0.0017576477737748064
# 		Validation Loss: 0.0002
# 		Validation Accuracy: 99.38%
# 	Epoch 6:
# 		Train Loss: 0.00027631118609861005
# 		Validation Loss: 0.0001
# 		Validation Accuracy: 98.75%
# 	Epoch 7:
# 		Train Loss: 9.889515163195029e-05
# 		Validation Loss: 0.0001
# 		Validation Accuracy: 98.75%
# 	Epoch 8:
# 		Train Loss: 7.07606700643737e-05
# 		Validation Loss: 0.0001
# 		Validation Accuracy: 98.75%
# 	Epoch 9:
# 		Train Loss: 5.780066557008468e-05
# 		Validation Loss: 0.0001
# 		Validation Accuracy: 98.75%
# Fold 2:
# 	Epoch 0:
# 		Train Loss: 0.21374312421539798
# 		Validation Loss: 0.0005
# 		Validation Accuracy: 97.50%
# 	Epoch 1:
# 		Train Loss: 0.011810771998284508
# 		Validation Loss: 0.0002
# 		Validation Accuracy: 99.38%
# 	Epoch 2:
# 		Train Loss: 0.008604233516666681
# 		Validation Loss: 0.0002
# 		Validation Accuracy: 98.75%
# 	Epoch 3:
# 		Train Loss: 0.005791587791088659
# 		Validation Loss: 0.0002
# 		Validation Accuracy: 98.75%
# 	Epoch 4:
# 		Train Loss: 0.0050532606664603465
# 		Validation Loss: 0.0005
# 		Validation Accuracy: 99.38%
# 	Epoch 5:
# 		Train Loss: 0.0018222503544009783
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 99.38%
# 	Epoch 6:
# 		Train Loss: 7.879841824660616e-05
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 99.38%
# 	Epoch 7:
# 		Train Loss: 4.373579448682108e-05
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 99.38%
# 	Epoch 8:
# 		Train Loss: 2.4651219553817328e-05
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 99.38%
# 	Epoch 9:
# 		Train Loss: 1.908799061069999e-05
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 99.38%
# Fold 3:
# 	Epoch 0:
# 		Train Loss: 0.1850940701784566
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 98.12%
# 	Epoch 1:
# 		Train Loss: 0.01924138831809614
# 		Validation Loss: 0.0004
# 		Validation Accuracy: 97.50%
# 	Epoch 2:
# 		Train Loss: 0.00039347006540708663
# 		Validation Loss: 0.0002
# 		Validation Accuracy: 99.38%
# 	Epoch 3:
# 		Train Loss: 0.00034730770965722967
# 		Validation Loss: 0.0002
# 		Validation Accuracy: 99.38%
# 	Epoch 4:
# 		Train Loss: 4.5844559204510914e-05
# 		Validation Loss: 0.0002
# 		Validation Accuracy: 99.38%
# 	Epoch 5:
# 		Train Loss: 3.591554438031608e-05
# 		Validation Loss: 0.0002
# 		Validation Accuracy: 99.38%
# 	Epoch 6:
# 		Train Loss: 2.986272321123806e-05
# 		Validation Loss: 0.0001
# 		Validation Accuracy: 99.38%
# 	Epoch 7:
# 		Train Loss: 2.584861332621813e-05
# 		Validation Loss: 0.0001
# 		Validation Accuracy: 99.38%
# 	Epoch 8:
# 		Train Loss: 2.2911655767643425e-05
# 		Validation Loss: 0.0001
# 		Validation Accuracy: 99.38%
# 	Epoch 9:
# 		Train Loss: 2.0634854664081104e-05
# 		Validation Loss: 0.0001
# 		Validation Accuracy: 99.38%
# Fold 4:
# 	Epoch 0:
# 		Train Loss: 0.17502098260738422
# 		Validation Loss: 0.0002
# 		Validation Accuracy: 98.12%
# 	Epoch 1:
# 		Train Loss: 0.015642682741963655
# 		Validation Loss: 0.0013
# 		Validation Accuracy: 96.88%
# 	Epoch 2:
# 		Train Loss: 0.0021215193128682587
# 		Validation Loss: 0.0002
# 		Validation Accuracy: 97.50%
# 	Epoch 3:
# 		Train Loss: 0.00037819985714122596
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 98.12%
# 	Epoch 4:
# 		Train Loss: 2.9075397037559014e-05
# 		Validation Loss: 0.0004
# 		Validation Accuracy: 98.12%
# 	Epoch 5:
# 		Train Loss: 1.7647176042601133e-05
# 		Validation Loss: 0.0004
# 		Validation Accuracy: 98.12%
# 	Epoch 6:
# 		Train Loss: 1.4586749978207081e-05
# 		Validation Loss: 0.0004
# 		Validation Accuracy: 98.12%
# 	Epoch 7:
# 		Train Loss: 1.2860355991506366e-05
# 		Validation Loss: 0.0004
# 		Validation Accuracy: 98.75%
# 	Epoch 8:
# 		Train Loss: 1.1616721650398176e-05
# 		Validation Loss: 0.0004
# 		Validation Accuracy: 98.75%
# 	Epoch 9:
# 		Train Loss: 1.0646709102957175e-05
# 		Validation Loss: 0.0004
# 		Validation Accuracy: 98.75%
# Fold 5:
# 	Epoch 0:
# 		Train Loss: 0.18611860655364582
# 		Validation Loss: 0.0006
# 		Validation Accuracy: 96.25%
# 	Epoch 1:
# 		Train Loss: 0.01526521287767082
# 		Validation Loss: 0.0005
# 		Validation Accuracy: 98.12%
# 	Epoch 2:
# 		Train Loss: 0.014857461206031531
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 98.12%
# 	Epoch 3:
# 		Train Loss: 0.032071062039656796
# 		Validation Loss: 0.0030
# 		Validation Accuracy: 93.75%
# 	Epoch 4:
# 		Train Loss: 0.02589360131763101
# 		Validation Loss: 0.0010
# 		Validation Accuracy: 97.50%
# 	Epoch 5:
# 		Train Loss: 0.03173746264856163
# 		Validation Loss: 0.0005
# 		Validation Accuracy: 98.12%
# 	Epoch 6:
# 		Train Loss: 0.00022170271674895047
# 		Validation Loss: 0.0007
# 		Validation Accuracy: 98.12%
# 	Epoch 7:
# 		Train Loss: 0.0001771723590053398
# 		Validation Loss: 0.0007
# 		Validation Accuracy: 98.12%
# 	Epoch 8:
# 		Train Loss: 0.0001257070388135162
# 		Validation Loss: 0.0007
# 		Validation Accuracy: 98.12%
# 	Epoch 9:
# 		Train Loss: 8.807133446566695e-05
# 		Validation Loss: 0.0007
# 		Validation Accuracy: 98.12%
