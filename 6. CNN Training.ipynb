# %%
# %run "./5. CNN Definition.ipynb"
# Out:
# X: (800, 360, 25)
# Y: (800,)

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter
from sklearn.model_selection import StratifiedKFold

# %%
model_dir = "models"

num_samples = 800
num_features = 360
seq_length = 25
num_classes = 2

num_epochs = 10
num_folds = 5

learning_rate = 0.001
batch_size = 32

# %%
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# %%
k_sampler = StratifiedKFold(n_splits=num_folds, shuffle=True)

# Create a SummaryWriter object
writer = SummaryWriter()

for fold_index, (train_indices, test_indices) in enumerate(k_sampler.split(X, Y)):
    print(f"Fold {fold_index + 1}:")

    np.save(f'./models/model_{fold_index + 1}_train.npy', train_indices)
    np.save(f'./models/model_{fold_index + 1}_test.npy', test_indices)

    train_length = len(train_indices)
    test_length = len(test_indices)
    x_train, y_train = X[train_indices], Y[train_indices]
    x_test, y_test = X[test_indices], Y[test_indices]

    model = MultiFeatureTimeSeries()
    model = model.float()
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    for epoch_index in range(num_epochs):
        print(f"\tEpoch {epoch_index}:")

        train_loss = 0.0

        # Model Training:
        model.train()
        for batch_index in range(0, train_length, batch_size):
            inputs = torch.from_numpy(x_train[batch_index: batch_index + batch_size]).float()
            labels = torch.from_numpy(y_train[batch_index: batch_index + batch_size]).long()

            optimizer.zero_grad()
            
            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Backward pass
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        avg_train_loss = train_loss / (train_length // batch_size)
        print("\t\tTrain Loss:", avg_train_loss)

        # Write training loss to TensorBoard
        writer.add_scalar('Loss/Train', avg_train_loss, fold_index * num_epochs + epoch_index)


        val_loss = 0.0
        correct = 0
        total = 0

        # Model Evaluation:
        model.eval()
        with torch.no_grad():
            inputs = torch.from_numpy(x_test).float()
            labels = torch.from_numpy(y_test).long()

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            # Compute accuracy
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        # Print validation loss and accuracy
        print(f"\t\tValidation Loss: {val_loss / test_length:.4f}")
        print(f"\t\tValidation Accuracy: {(100 * correct / total):.2f}%")

        # Write validation loss and accuracy to TensorBoard
        writer.add_scalar('Loss/Validation', val_loss / test_length, fold_index * num_epochs + epoch_index)
        writer.add_scalar('Accuracy/Validation', 100 * correct / total, fold_index * num_epochs + epoch_index)
    
    # Save the model.
    torch.save(model, f'./models/model_{fold_index + 1}.pth')

# Close the SummaryWriter
writer.close()
# Out:
# Fold 1:
# 	Epoch 0:
# 		Train Loss: 0.2705450381268747
# 		Validation Loss: 0.0006
# 		Validation Accuracy: 96.88%
# 	Epoch 1:
# 		Train Loss: 0.01648529102676548
# 		Validation Loss: 0.0009
# 		Validation Accuracy: 95.62%
# 	Epoch 2:
# 		Train Loss: 0.007171165623094567
# 		Validation Loss: 0.0005
# 		Validation Accuracy: 96.88%
# 	Epoch 3:
# 		Train Loss: 0.0001820702210352465
# 		Validation Loss: 0.0004
# 		Validation Accuracy: 97.50%
# 	Epoch 4:
# 		Train Loss: 0.0001325893595094385
# 		Validation Loss: 0.0005
# 		Validation Accuracy: 96.88%
# 	Epoch 5:
# 		Train Loss: 0.00010108782050792798
# 		Validation Loss: 0.0005
# 		Validation Accuracy: 96.88%
# 	Epoch 6:
# 		Train Loss: 8.249151067047933e-05
# 		Validation Loss: 0.0005
# 		Validation Accuracy: 96.88%
# 	Epoch 7:
# 		Train Loss: 7.002619220202178e-05
# 		Validation Loss: 0.0005
# 		Validation Accuracy: 96.88%
# 	Epoch 8:
# 		Train Loss: 6.0807222280345743e-05
# 		Validation Loss: 0.0005
# 		Validation Accuracy: 96.88%
# 	Epoch 9:
# 		Train Loss: 5.359815645533672e-05
# 		Validation Loss: 0.0005
# 		Validation Accuracy: 96.88%
# Fold 2:
# 	Epoch 0:
# 		Train Loss: 0.2362323021166958
# 		Validation Loss: 0.0012
# 		Validation Accuracy: 95.62%
# 	Epoch 1:
# 		Train Loss: 0.0035483804946579768
# 		Validation Loss: 0.0006
# 		Validation Accuracy: 97.50%
# 	Epoch 2:
# 		Train Loss: 0.001182251497772313
# 		Validation Loss: 0.0005
# 		Validation Accuracy: 96.88%
# 	Epoch 3:
# 		Train Loss: 3.009340590551801e-05
# 		Validation Loss: 0.0006
# 		Validation Accuracy: 96.25%
# 	Epoch 4:
# 		Train Loss: 2.9612304473403128e-05
# 		Validation Loss: 0.0006
# 		Validation Accuracy: 96.25%
# 	Epoch 5:
# 		Train Loss: 2.619325804573691e-05
# 		Validation Loss: 0.0006
# 		Validation Accuracy: 96.25%
# 	Epoch 6:
# 		Train Loss: 2.30784524674732e-05
# 		Validation Loss: 0.0006
# 		Validation Accuracy: 96.25%
# 	Epoch 7:
# 		Train Loss: 2.0625348584246693e-05
# 		Validation Loss: 0.0006
# 		Validation Accuracy: 96.25%
# 	Epoch 8:
# 		Train Loss: 1.8668976494495837e-05
# 		Validation Loss: 0.0006
# 		Validation Accuracy: 96.25%
# 	Epoch 9:
# 		Train Loss: 1.705880060853815e-05
# 		Validation Loss: 0.0006
# 		Validation Accuracy: 96.25%
# Fold 3:
# 	Epoch 0:
# 		Train Loss: 0.1509196724742651
# 		Validation Loss: 0.0001
# 		Validation Accuracy: 99.38%
# 	Epoch 1:
# 		Train Loss: 0.014853670872651038
# 		Validation Loss: 0.0000
# 		Validation Accuracy: 100.00%
# 	Epoch 2:
# 		Train Loss: 0.03201715766032862
# 		Validation Loss: 0.0007
# 		Validation Accuracy: 97.50%
# 	Epoch 3:
# 		Train Loss: 0.044619827468135934
# 		Validation Loss: 0.0002
# 		Validation Accuracy: 98.75%
# 	Epoch 4:
# 		Train Loss: 0.028496467763631017
# 		Validation Loss: 0.0001
# 		Validation Accuracy: 99.38%
# 	Epoch 5:
# 		Train Loss: 0.010062829910739878
# 		Validation Loss: 0.0006
# 		Validation Accuracy: 98.12%
# 	Epoch 6:
# 		Train Loss: 0.00019884158378431495
# 		Validation Loss: 0.0005
# 		Validation Accuracy: 98.12%
# 	Epoch 7:
# 		Train Loss: 5.001486939804067e-05
# 		Validation Loss: 0.0004
# 		Validation Accuracy: 98.12%
# 	Epoch 8:
# 		Train Loss: 3.090234795237734e-05
# 		Validation Loss: 0.0004
# 		Validation Accuracy: 98.12%
# 	Epoch 9:
# 		Train Loss: 2.386388931050476e-05
# 		Validation Loss: 0.0004
# 		Validation Accuracy: 98.12%
# Fold 4:
# 	Epoch 0:
# 		Train Loss: 0.2226880329893902
# 		Validation Loss: 0.0004
# 		Validation Accuracy: 96.88%
# 	Epoch 1:
# 		Train Loss: 0.0330402321931615
# 		Validation Loss: 0.0008
# 		Validation Accuracy: 97.50%
# 	Epoch 2:
# 		Train Loss: 0.002255351104389547
# 		Validation Loss: 0.0005
# 		Validation Accuracy: 97.50%
# 	Epoch 3:
# 		Train Loss: 0.0007880610089614493
# 		Validation Loss: 0.0007
# 		Validation Accuracy: 97.50%
# 	Epoch 4:
# 		Train Loss: 7.09151769399341e-05
# 		Validation Loss: 0.0009
# 		Validation Accuracy: 97.50%
# 	Epoch 5:
# 		Train Loss: 6.571149722560677e-05
# 		Validation Loss: 0.0009
# 		Validation Accuracy: 97.50%
# 	Epoch 6:
# 		Train Loss: 5.55775716492235e-05
# 		Validation Loss: 0.0009
# 		Validation Accuracy: 97.50%
# 	Epoch 7:
# 		Train Loss: 4.725625585422222e-05
# 		Validation Loss: 0.0009
# 		Validation Accuracy: 97.50%
# 	Epoch 8:
# 		Train Loss: 4.111459233229198e-05
# 		Validation Loss: 0.0009
# 		Validation Accuracy: 97.50%
# 	Epoch 9:
# 		Train Loss: 3.641183866989195e-05
# 		Validation Loss: 0.0009
# 		Validation Accuracy: 97.50%
# Fold 5:
# 	Epoch 0:
# 		Train Loss: 0.286229976802133
# 		Validation Loss: 0.0001
# 		Validation Accuracy: 100.00%
# 	Epoch 1:
# 		Train Loss: 0.004408369578595739
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 98.75%
# 	Epoch 2:
# 		Train Loss: 0.0005320325748471077
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 99.38%
# 	Epoch 3:
# 		Train Loss: 0.00012182608852526756
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 99.38%
# 	Epoch 4:
# 		Train Loss: 8.851882857925375e-05
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 99.38%
# 	Epoch 5:
# 		Train Loss: 7.205433366834768e-05
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 99.38%
# 	Epoch 6:
# 		Train Loss: 6.176725196382904e-05
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 99.38%
# 	Epoch 7:
# 		Train Loss: 5.438416542347113e-05
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 99.38%
# 	Epoch 8:
# 		Train Loss: 4.8620348707117955e-05
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 99.38%
# 	Epoch 9:
# 		Train Loss: 4.389080581859162e-05
# 		Validation Loss: 0.0003
# 		Validation Accuracy: 99.38%
